# %%
from selenium import webdriver

# %%
driver = webdriver.PhantomJS(executable_path=r'C:\phantomjs-2.1.1-windows\bin\phantomjs.exe')

# %%
driver.get("https://esports-betonline.ultraplay.net/esports/today")
# This will get the initial html - before javascript
html1 = driver.page_source

# This will get the html after on-load javascript
html2 = driver.execute_script("return document.documentElement.innerHTML;")

# %%
print(html2)
# Out:
# <head><style type="text/css">.ng-animate.item:not(.left):not(.right){-webkit-transition:0s ease-in-out left;transition:0s ease-in-out left}</style><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}</style>
#     <title data-ng-controller="TitleController" data-ng-init="setTitle('betonline')" data-ng-bind="getTitle()" class="ng-binding ng-scope">Today - BetOnline</title>
#     <meta charset="utf-8">
#     <base href="/">
#     <meta name="fragment" content="!">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="ROBOTS" content="INDEX, FOLLOW">
#     <meta name="description" data-ng-controller="TitleController" data-ng-init="setMetaDescription('Join betonline')" content="Join betonline" class="ng-scope">
#     <link rel="shortcut icon" type="image/x-icon" href="/Content/images/fav-icon.png">
#
#     <link rel="icon" href="data:;base64,iVBORw0KGgo=">
#
#     <meta property="fb:app_id" content="852460694777330">
#
#     <meta property="og:site_name" content="betonline">
#
#     <meta property="og:image:width" content="600">
#     <meta property="og:image:height" content="314">
#     <meta property="og:type" content="website">
#
#     <link href="/bundles/content/css/vendor?v=pqSxEvDZpURk5Zkamfj2yn_tfbyMpayayNxE8EcG-ac1" rel="stylesheet">
#
#     <link href="/bundles/content/css/app?v=CTzumzuakg8cDASbRtVWbOgvG2L82HgFltHp4N_a_MM1" rel="stylesheet">
#
#
#     <link href="https://fonts.googleapis.com/css?family=Catamaran:400,200,500,700" rel="stylesheet" type="text/css">
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css">
#
#     <script src="https://webapi.ultraplay.net/js/jquery"></script>
#
#     <script src="https://webapi.ultraplay.net/scripts/simple-slider.min.js"></script>
#
#     <script src="https://webapi.ultraplay.net/js/signalr"></script>
#
#     <script src="/signalr/hubs"></script>
#
#     <script src="https://webapi.ultraplay.net/js/angular"></script>
#
#
#
#
#
#     <script type="text/javascript">
#         var Constants = Constants || {};
#         Constants.Server = {"TicketStatuses":["Pending","Cancelled","Win","Lost","Refund","HalfWin","HalfLose"],"Payments":{"All":"All","WireTransfer":"Wire Transfer","CreditCard":"Credit Card","WesternUnion":"Western Union","MoneyGram":"Money Gram","Neteller":"Neteller","Cashier":"Cashier","BonusPoints":"Bonus Points","Affiliates":"Affiliates","CompsProgram":"Comps Program","Jackpot":"Jackpot","PayPro":"PayPro","AgentPayment":"Agent Payment","Bitcoin":"Bitcoin","InternalTransfer":"Internal Transfer","IPS":"IPS","EMerchantPayCreditCard":"Credit card EMP","Litecoin":"Litecoin","Peercoin":"Peercoin","Dogecoin":"Dogecoin","Skrill":"Skrill","Sharjiran":"Sharjiran","Voucher":"Voucher","EpayBg":"EpayBg","UnionPay":"Unionpay China","Rebate":"Rebate","EMerchantPayNeteller":"Neteller EMP","EMerchantPaySofort":"Sofort","EMerchantPayMoneta":"Moneta","EMerchantPayINPay":"InPay","EMerchantPayYandex":"Yandex","EMerchantPayPPro":"PPro","EMerchantPayOthers":"EMP others","IPayments":"i-Payments","IWallet":"IWallet","GoPay":"GoPay","DaddyPay":"网银","WeChatPay":"微信支付","Coinever":"Coinever","CCARD":"CCARD","Rfupay":"微信支付","EcoPayz":"EcoPayz","Apco":"Bank Transfer","Moneta":"moneta.ru","MonetaYandex":"yandex.money","MonetaQiwi":"QIWI","SoftSwissTransaction":"SoftSwissTransaction","ApcoDeposit":"Apco Deposit","ApcoTurkishPayments":"Tükiye Ödemesi","ApcoWithdraw":"Apco Withdraw","ApcoPaykasaVoucher":"APCO Paykasa Voucher","ApcoVisaCard":"APCO VISA","ApcoCashixirVoucher":"APCO Cashixir Voucher","ApcoJetonVoucher":"APCO Jeton Voucher","Skinpay":"Skinpay","DaddyPayBankTransfer":"Bank Transfer","BankTransfer":"Bank Transfer","PaymenttrBankTransfer":"Paymenttr Bank Transfer","PaymenttrMobileTransfer":"Paymenttr Mobile Transfer","Alipay":"支付宝","PatoWechatPay":"微信支付","PatoAlipay":"支付宝","PatoBankpay":"Bank Pay","Skinwallet":"Skinwallet","PaymenttrManual":"Paymenttr Manual"},"VirtualSports":{"soccer":"Virtual Soccer","basketball":"Virtual Basketball","tennis":"Virtual Tennis"},"SiteID":58};
#         Constants.TimeLocalization = {"Days":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"DaysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"Months":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]};
#         Constants.UIMessages = {
#             withdrawalSuccessMessage: 'Please wait a few minutes for us to process your request. Contact live support if it takes longer than usual.'
#         };
#     </script>
# </head>
# <body class="" data-ng-controller="ModalsController">
#     <!-- Wrapper required for sidebar transitions -->
#     <div class="st-container">
#         <!-- Fixed navbar -->
# <div class="navbar navbar-main navbar-primary navbar-fixed-top nav-background" role="navigation">
#     <div class="container-fluid">
#         <div class="navbar-header">
#
#             <a href="#sidebar-menu" data-effect="st-effect-1" data-toggle="sidebar-menu" class="toggle pull-left visible-xs"><i class="fa fa-ellipsis-v"></i></a>
#
#             <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#main-nav">
#                 <span class="sr-only">Toggle navigation</span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#             </button>
#             <a href="#sidebar-menu-right" data-toggle="sidebar-menu" data-effect="st-effect-1" class="toggle pull-right visible-xs"><i class="fa fa-ticket"></i></a>
#
#         </div>
#         <!-- Collect the nav links, forms, and other content for toggling -->
#         <div class="collapse navbar-collapse ng-scope" id="main-nav" data-ng-controller="CustomNavMenuController">
#             <ul class="nav navbar-nav">
#                 <li data-ng-class="isActiveTab('esports') ? 'active' : ''" class="active">
#                     <a href="/esports/today">ESPORTS</a>
#                 </li>
#
#
#
#
#                 <li class="dropdown" data-dropdown="open" data-ng-class="{active : isActiveTab('results')}">
#                     <a href="#" class="dropdown-toggle user">
#                         RESULTS <span class="caret"></span>
#                     </a>
#                     <ul class="dropdown-menu">
#                         <li><a href="/results"> All Esports</a></li>
#                         <li><a href="/results-outright">Outright</a></li>
#                     </ul>
#                 </li>
#                 <li class="dropdown flags ng-scope" data-ng-controller="LanguageController" data-ng-class="languagesState">
#                     <!-- ngIf: language --><a href="#" class="dropdown-toggle ng-scope" data-toggle="dropdown" aria-expanded="true" data-ng-click="accordionLanguages()" data-ng-if="language">
#                         <img data-ng-src="/content/images/flags/Flag_of_the_United_States.svg" alt="United States" style="width: 100%; height: auto; display: block; margin-left: auto; margin-right: auto;" src="/content/images/flags/Flag_of_the_United_States.svg">
#                         <span class="caret"></span>
#                     </a><!-- end ngIf: language -->
#                     <!-- ngIf: language --><ul class="dropdown-menu min-width-none ng-scope" role="menu" data-ng-if="language">
#                         <!-- ngRepeat: language in languages --><li class="active text-center ng-scope" data-ng-click="setLanguage(language)" data-ng-repeat="language in languages">
#                             <a>
#                                 <img data-ng-src="/content/images/flags/Flag_of_the_United_States.svg" alt="United States" style="width: 100%; height: auto; display: block; margin-left: auto; margin-right: auto;" src="/content/images/flags/Flag_of_the_United_States.svg">
#                             </a>
#                         </li><!-- end ngRepeat: language in languages --><li class="active text-center ng-scope" data-ng-click="setLanguage(language)" data-ng-repeat="language in languages">
#                             <a>
#                                 <img data-ng-src="/content/images/flags/Flag_of_China.svg" alt="China" style="width: 100%; height: auto; display: block; margin-left: auto; margin-right: auto;" src="/content/images/flags/Flag_of_China.svg">
#                             </a>
#                         </li><!-- end ngRepeat: language in languages -->
#                     </ul><!-- end ngIf: language -->
#                 </li>
#
#
#             </ul>
#
#             <ul class="nav navbar-nav navbar-right ng-scope" data-ng-controller="AccountController">
#
#             </ul>
#
#
#
#         </div>
#         <!-- /.navbar-collapse -->
#
#     </div>
#
#
# </div>
#
#         <!-- ngView:  --><div data-ng-view="" class="view ng-scope"><!-- Sidebar component with st-effect-1 (set on the toggle button within the navbar) -->
# <div class="sidebar left sidebar-size-2 sidebar-offset-0 sidebar-visible-desktop sidebar-visible-mobile sidebar-skin-dark sports-sidebar ng-scope" id="sidebar-menu" data-ng-controller="CustomLeftSidebarController" data-type="collapse" style="display:none">
#     <div data-scrollable="">
#         <div class="sidebar-block">
#             <div class="padding-bottom-none text-center">
#                 <h4 class="margin-none ng-binding">23:14:24</h4><small class="ng-binding">December 6, 2017 (GMT-8)</small>
#             </div>
#         </div>
#
#         <div class="sidebar-block sidebar-search ng-scope" data-ng-controller="CustomSearchController">
#             <div class="padding-bottom-none form-group input-group">
#                 <input type="text" class="form-control ng-pristine ng-untouched ng-valid" placeholder="Team Search" data-ng-model="keyword" data-ng-change="keywordChanged()">
#                 <span class="input-group-btn">
#                     <button class="btn btn-primary" type="button" data-ng-click="keywordChanged()"><i class="fa fa-search"></i></button>
#                 </span>
#             </div>
#
#         </div>
#
#         <ul class="sidebar-menu">
#             <li class="">
#                 <a href="/esports/favorites">
#                     <i class="fa fa-fw fa-star"></i>
#                     <span>Favorites</span>
#
#                 </a>
#             </li>
#             <!-- ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
#
#                 <a href="esports/today/3683" title="Counter-Strike" class="collapsed">
#
#                     <div class="sprite-icon-thumbnail icon-4 counter-strike undefined" format-name-to-class="" format-category-name="category.Name" format-sporttype-name=""></div>
#                     <span class="ng-binding">Counter-Strike</span>
#
#                 </a>
#                 <ul class="collapse" id="category_3683">
#                     <!-- ngIf: category.LiveMatchesCount > 0 -->
#                     <!-- ngRepeat: tournament in category.tournaments -->
#                 </ul>
#             </li><!-- end ngRepeat: category in categories -->
#         </ul>
#     </div>
# </div>
# <!-- Sidebar component with st-effect-1 (set on the toggle button within the navbar) -->
# <div class="sidebar right sidebar-size-3 sidebar-offset-0 sidebar-visible-desktop sidebar-visible-mobile sidebar-skin-dark ng-scope" id="sidebar-menu-right" data-ng-controller="CustomBetslipController">
#     <div data-scrollable="">
#         <div class="sidebar-block">
#             <div class="">
#                 <div class="text-center">BET SLIP <!-- ngIf: selections.length > 0 --> </div>
#             </div>
#         </div>
#
#         <!-- if no bet slip-->
#         <!-- ngIf: selections.length == 0 && TicketItems.length == 0 --><div class="sidebar-block text-center ng-scope" data-ng-if="selections.length == 0 &amp;&amp; TicketItems.length == 0">
#             <p>Your betslip is empty. </p>
#             <small>Select events to place bets.</small>
#         </div><!-- end ngIf: selections.length == 0 && TicketItems.length == 0 -->
#         <!-- /end if no bet slip -->
#
#         <!-- ngIf: selections.length > 0 || TicketItems.length > 0 -->
#
#     </div>
# </div>
#
# <!-- content push wrapper -->
# <div class="st-pusher ng-scope" id="content" data-ng-init="setBodyClass(); setTitle('Today - BetOnline')">
#     <!-- sidebar effects INSIDE of st-pusher: -->
#     <!-- st-effect-3, st-effect-6, st-effect-7, st-effect-8, st-effect-14 -->
#     <!-- this is the wrapper for the content -->
#     <div class="st-content">
#         <nav class="navbar navbar-subnav navbar-static-top margin-bottom-none ng-scope" role="navigation" data-ng-controller="MatchTypeNavigationController">
#
#     <!-- Collect the nav links, forms, and other content for toggling -->
#     <div class="" id="subnav" aria-expanded="false" style="height: 1px;">
#         <ul class="nav nav-justified">
#             <li data-ng-class="isActiveTab('live') ? 'active' : ''">
#                 <a href="/esports/live">
#                     <i class="fa fa-fw fa-dot-circle-o"></i>
#                     <span class="hidden-xs">LIVE</span>
#
#                 </a>
#             </li>
#             <li data-ng-class="isActiveTab('today') ? 'active' : ''" class="active">
#                 <a href="/esports/today">
#                     <i class="fa fa-fw icon-calendar-1"></i>
#                     <span class="hidden-xs">TODAY</span>
#
#                 </a>
#             </li>
#             <li data-ng-class="isActiveTab('program') ? 'active' : ''">
#                 <a href="/esports/program">
#                     <i class="fa fa-fw icon-calendar-2"></i>
#                     <span class="hidden-xs">EARLY MARKETS</span>
#
#                 </a>
#             </li>
#             <li data-ng-class="isActiveTab('outrights') ? 'active' : ''">
#                 <a href="/esports/outrights">
#                     <i class="fa fa-fw fa-trophy"></i>
#                     <span class="hidden-xs">OUTRIGHT</span>
#
#                 </a>
#             </li>
#
#         </ul>
#
#     </div>
#     <!-- /.navbar-collapse -->
# </nav>
#
#         <!-- extra div for emulating position:fixed of the menu -->
#         <div class="st-content-inner">
#             <div class="container-fluid">
#                 <!-- insert content here -->
#                 <div class="panel-padded ng-scope" data-ng-controller="ViewSettingsController">
#     <div class="row">
#         <div class="col-xs-12 pull-right">
#             <div class="dropdown pull-right" data-dropdown="open">
#                 <div class="btn-outline btn-xs dropdown-toggle ng-binding" type="button" data-ng-click="clickTimezone()">
#                     23:14:24 GMT-8
#                     <span class="caret"></span>
#                 </div>
#                 <ul class="dropdown-menu">
#                     <!-- ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">19:14:24 GMT-12</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">20:14:24 GMT-11</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">21:14:24 GMT-10</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">22:14:24 GMT-9</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">23:14:24 GMT-8</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">00:14:24 GMT-7</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">01:14:24 GMT-6</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">02:14:24 GMT-5 (EST)</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">03:14:24 GMT-4</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">04:14:24 GMT-3</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">05:14:24 GMT-2</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">06:14:24 GMT-1</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">07:14:24 GMT</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">08:14:24 GMT+1</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">09:14:24 GMT+2</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">10:14:24 GMT+3</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">11:14:24 GMT+4</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">12:14:24 GMT+5</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">13:14:24 GMT+6</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">14:14:24 GMT+7</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)" class="ng-scope"><a href="#" class="ng-binding">15:14:24 GMT+8</a></li><!-- end ngRepeat: item in timezones --><li data-ng-repeat="item in timezones" data-ng-click="setTimezone(item)"  ...
#                 </ul>
#             </div>
#
#             <div class="dropdown pull-right capitalize" data-dropdown="open">
#                 <div class="btn-outline btn-xs dropdown-toggle ng-binding" type="button" data-ng-click="clickOddView()">
#                     Decimal
#                     <span class="caret"></span>
#                 </div>
#                 <ul class="dropdown-menu">
#                     <!-- ngRepeat: item in oddFormats --><li data-ng-repeat="item in oddFormats" data-ng-click="setOddFormat(item.Value)" class="ng-scope"><a href="#" class="ng-binding">American</a></li><!-- end ngRepeat: item in oddFormats --><li data-ng-repeat="item in oddFormats" data-ng-click="setOddFormat(item.Value)" class="ng-scope"><a href="#" class="ng-binding">Decimal</a></li><!-- end ngRepeat: item in oddFormats --><li data-ng-repeat="item in oddFormats" data-ng-click="setOddFormat(item.Value)" class="ng-scope"><a href="#" class="ng-binding">Fractional</a></li><!-- end ngRepeat: item in oddFormats --><li data-ng-repeat="item in oddFormats" data-ng-click="setOddFormat(item.Value)" class="ng-scope"><a href="#" class="ng-binding">Hong Kong</a></li><!-- end ngRepeat: item in oddFormats -->
#                 </ul>
#             </div>
#         </div>
#
#     </div>
# </div>
#
#                 <div class="loader loader-sport-block" data-ng-show="matches == null || isLoadingMatches">Loading...</div>
# <!-- start sport -->
# <!-- ngRepeat: category in categories | orderBy : 'Rank' : true --><!-- / end sport here -->
# <!-- start sport -->
# <!-- start sport mobile -->
# <!-- ngRepeat: category in categories | orderBy : 'Rank' : true --><!-- / end sport here -->
# <!-- / end content here -->
#
#             </div>
#
#         </div>
#         <!-- /st-content-inner -->
#     </div>
#     <!-- /st-content -->
# </div>
# </div>
#
#
#
#
#     </div>
#     <!-- /st-container -->
#     <!-- start match result modal -->
# <div class="modal modal-match-result fade modal-sidebets" data-backdrop="static" data-keyboard="false">
#     <div class="modal-dialog">
#         <div class="v-cell">
#             <!-- ngIf: showMatchResultModalMatchId -->
#         </div>
#     </div>
# </div>
#
#     <!-- start bet error modal -->
# <div class="modal fade modal-default modal-bet-error" tabindex="-1" role="dialog" aria-labelledby="myModalLabel" aria-hidden="true">
#     <div class="modal-dialog">
#         <div class="modal-content modal-sm">
#             <!-- Modal Header -->
#             <div class="modal-header">
#                 <button type="button" class="close" data-dismiss="modal">
#                     <span aria-hidden="true">×</span>
#                     <span class="sr-only">Close</span>
#                 </button>
#
#             </div>
#
#             <!-- Modal Body -->
#             <div class="modal-body text-center">
#                 <i class="fa fa-fw fa-warning fa-5x"></i>
#                 <p class="modal-error-message">This is a message</p>
#              </div>
#
#             <!-- Modal Footer -->
#             <div class="modal-footer padding-none">
#                 <button type="button" class="btn btn-primary" data-dismiss="modal">
#                     OK
#                 </button>
#             </div>
#         </div>
#     </div>
# </div>
# <!-- end bet error modal -->
#
#
# <!-- start login modal -->
# <div class="modal fade modal-default modal-login" tabindex="-1" role="dialog" aria-hidden="true">
#     <div class="modal-dialog ng-scope" data-ng-controller="CustomAuthorizationController">
#         <div class="modal-content modal-sm">
#             <!-- Modal Header -->
#             <div class="modal-header">
#                 <button type="button" class="close" data-dismiss="modal">
#                     <span aria-hidden="true">×</span>
#                     <span class="sr-only">Close</span>
#                 </button>
#                 <h4 class="modal-title" id="myModalLabel">
#                     Login
#                 </h4>
#             </div>
#             <form class="form-horizontal ng-pristine ng-valid">
#                 <!-- Modal Body -->
#                 <div class="modal-body ng-binding">
#
#
#
#                     <div class="form-group">
#
#                         <div class="col-sm-12">
#                             <div class="input-group">
#                                 <span class="input-group-addon"><i class="fa fa-user"></i></span>
#                                 <input type="text" class="form-control login-username ng-pristine ng-untouched ng-valid" name="login_username" autocomplete="off" data-ng-model="loginModel.Login" tabindex="1" placeholder="Username">
#                             </div>
#                         </div>
#                     </div>
#                     <div class="form-group">
#
#                         <div class="col-sm-12">
#                             <div class="input-group">
#                                 <span class="input-group-addon"><i class="fa fa-lock"></i></span>
#                                 <input type="password" class="form-control ng-pristine ng-untouched ng-valid" name="login_password" autocomplete="off" data-ng-model="loginModel.Password" tabindex="2" placeholder="Password">
#                             </div>
#                         </div>
#                     </div>
#                     <div class="form-group">
#                         <div id="captcha" class="col-sm-12">
#                             <div ng-show="isCaptchaAvaible()" class="input-group ng-hide">
#     <span class="input-group-addon"><i class="fa fa-warning"></i></span>
#     <input type="text" placeholder="Captcha text" name="login_captchaResponse" class="form-control ng-pristine ng-untouched ng-valid" autocomplete="off" data-ng-model="loginModel.CaptchaResponse">
# </div>
# <!-- ngIf: isCaptchaAvaible() -->
#                         </div>
#                     </div>
#                     <div class="row">
#                         <div class="col-sm-6">
#                             <a href="#" data-ng-click="openModal('modal-registration')">
#                                 <small> Create an account </small>
#                             </a>
#                         </div>
#                         <div class="col-sm-6">
#                             <a href="#" data-ng-click="openModal('modal-lost-password')">
#                                 <small> Forgot password? </small>
#                             </a>
#                         </div>
#                     </div>
#
#                 </div>
#
#                 <!-- Modal Footer -->
#                 <div class="modal-footer padding-none">
#                     <input type="submit" class="btn btn-primary" tabindex="4" data-ng-click="loginClick(loginModel)" data-dismiss="modal" value="SIGN IN" autofocus="">
#                 </div>
#             </form>
#         </div>
#     </div>
# </div>
# <!-- end login modal -->
# <!-- start sign up modal -->
# <!-- ngIf: isRegistrationModalOpen -->
# <!-- end sign up modal --><!-- start reset password modal -->
# <!-- ngIf: isLostPasswordModalOpen -->
# <!-- end login modal -->
#
#     <script>
#         window.registrationValidationConstants = {
#             userNameLength: 'Username must be between 6 and 12 characters.',
#             userNameCharecters: 'Username must contain only numbers and letters.',
#             passwordLenght: 'Password must be between 6 and 12 characters.',
#             passwordAlphanumeric: 'Password must contain only numbers and letters.',
#             passwordConfirm: 'Both passwords are not the same.',
#             nameCharecters: 'Name must contain only letters.',
#             phoneNumber: 'Phone can only contain numbers.',
#             email: 'Should contain @ sign.',
#             invalidString: 'input must be a valid string.',
#             required: 'This field is required.',
#             propertyNotFound: 'Property does not exist.',
#             usernameLeastOneLetterAndNumber: 'Username must contain at least one letter and number.',
#             passwordLeastOneLetterAndNumber: 'Password must contain at least one letter and number.'
#         }
#     </script>
#
#
#
#     <!--CDN scripts-->
#     <script src="https://webapi.ultraplay.net/js"></script>
#
#     <script src="https://webapi.ultraplay.net/js/profile"></script>
#
#     <script src="https://webapi.ultraplay.net/js/register"></script>
#
#
#     <!--Local scripts-->
#     <script src="/bundles/scripts/vendor?v=TZNAw_3CRX8SZgcBa50fsdH18JuFH8KokeWh9kWPGX41"></script>
#
#     <script src="/bundles/content/js?v=6ZMWMHGGJiTg8jTAcY9imJeMcWhzI1OuAfOuM7JvNdk1"></script>
#
#
#
#
# </body>
