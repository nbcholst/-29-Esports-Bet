# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import numpy as np

# %%
driver = webdriver.PhantomJS(executable_path=r'C:\phantomjs-2.1.1-windows\bin\phantomjs.exe')
driver2 = webdriver.PhantomJS(executable_path=r'C:\phantomjs-2.1.1-windows\bin\phantomjs.exe')

# %%
driver.get("https://esports-betonline.ultraplay.net/esports/today")
driver2.get("https://esports-betonline.ultraplay.net/esports/program/0")

sleep(5)
html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
html2 = driver2.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
soup = BeautifulSoup(html, "html.parser")
soup2 = BeautifulSoup(html2, "html.parser")

# %%
# get soup
print(soup2)
# Out:
# <head><style type="text/css">.ng-animate.item:not(.left):not(.right){-webkit-transition:0s ease-in-out left;transition:0s ease-in-out left}</style><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}</style>
# <title class="ng-binding ng-scope" data-ng-bind="getTitle()" data-ng-controller="TitleController" data-ng-init="setTitle('betonline')">Early - BetOnline</title>
# <meta charset="utf-8"/>
# <base href="/"/>
# <meta content="!" name="fragment"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="INDEX, FOLLOW" name="ROBOTS"/>
# <meta class="ng-scope" content="Join betonline" data-ng-controller="TitleController" data-ng-init="setMetaDescription('Join betonline')" name="description"/>
# <link href="/Content/images/fav-icon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="data:;base64,iVBORw0KGgo=" rel="icon"/>
# <meta content="852460694777330" property="fb:app_id"/>
# <meta content="betonline" property="og:site_name"/>
# <meta content="600" property="og:image:width"/>
# <meta content="314" property="og:image:height"/>
# <meta content="website" property="og:type"/>
# <link href="/bundles/content/css/vendor?v=pqSxEvDZpURk5Zkamfj2yn_tfbyMpayayNxE8EcG-ac1" rel="stylesheet"/>
# <link href="/bundles/content/css/app?v=CTzumzuakg8cDASbRtVWbOgvG2L82HgFltHp4N_a_MM1" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Catamaran:400,200,500,700" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/>
# <script src="https://webapi.ultraplay.net/js/jquery"></script>
# <script src="https://webapi.ultraplay.net/scripts/simple-slider.min.js"></script>
# <script src="https://webapi.ultraplay.net/js/signalr"></script>
# <script src="/signalr/hubs"></script>
# <script src="https://webapi.ultraplay.net/js/angular"></script>
# <script type="text/javascript">
#         var Constants = Constants || {};
#         Constants.Server = {"TicketStatuses":["Pending","Cancelled","Win","Lost","Refund","HalfWin","HalfLose"],"Payments":{"All":"All","WireTransfer":"Wire Transfer","CreditCard":"Credit Card","WesternUnion":"Western Union","MoneyGram":"Money Gram","Neteller":"Neteller","Cashier":"Cashier","BonusPoints":"Bonus Points","Affiliates":"Affiliates","CompsProgram":"Comps Program","Jackpot":"Jackpot","PayPro":"PayPro","AgentPayment":"Agent Payment","Bitcoin":"Bitcoin","InternalTransfer":"Internal Transfer","IPS":"IPS","EMerchantPayCreditCard":"Credit card EMP","Litecoin":"Litecoin","Peercoin":"Peercoin","Dogecoin":"Dogecoin","Skrill":"Skrill","Sharjiran":"Sharjiran","Voucher":"Voucher","EpayBg":"EpayBg","UnionPay":"Unionpay China","Rebate":"Rebate","EMerchantPayNeteller":"Neteller EMP","EMerchantPaySofort":"Sofort","EMerchantPayMoneta":"Moneta","EMerchantPayINPay":"InPay","EMerchantPayYandex":"Yandex","EMerchantPayPPro":"PPro","EMerchantPayOthers":"EMP others","IPayments":"i-Payments","IWallet":"IWallet","GoPay":"GoPay","DaddyPay":"网银","WeChatPay":"微信支付","Coinever":"Coinever","CCARD":"CCARD","Rfupay":"微信支付","EcoPayz":"EcoPayz","Apco":"Bank Transfer","Moneta":"moneta.ru","MonetaYandex":"yandex.money","MonetaQiwi":"QIWI","SoftSwissTransaction":"SoftSwissTransaction","ApcoDeposit":"Apco Deposit","ApcoTurkishPayments":"Tükiye Ödemesi","ApcoWithdraw":"Apco Withdraw","ApcoPaykasaVoucher":"APCO Paykasa Voucher","ApcoVisaCard":"APCO VISA","ApcoCashixirVoucher":"APCO Cashixir Voucher","ApcoJetonVoucher":"APCO Jeton Voucher","Skinpay":"Skinpay","DaddyPayBankTransfer":"Bank Transfer","BankTransfer":"Bank Transfer","PaymenttrBankTransfer":"Paymenttr Bank Transfer","PaymenttrMobileTransfer":"Paymenttr Mobile Transfer","Alipay":"支付宝","PatoWechatPay":"微信支付","PatoAlipay":"支付宝","PatoBankpay":"Bank Pay","Skinwallet":"Skinwallet","PaymenttrManual":"Paymenttr Manual"},"VirtualSports":{"soccer":"Virtual Soccer","basketball":"Virtual Basketball","tennis":"Virtual Tennis"},"SiteID":58};
#         Constants.TimeLocalization = {"Days":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"DaysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"Months":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]};
#         Constants.UIMessages = {
#             withdrawalSuccessMessage: 'Please wait a few minutes for us to process your request. Contact live support if it takes longer than usual.'
#         };
#     </script>
# </head>
# <body class="" data-ng-controller="ModalsController">
# <!-- Wrapper required for sidebar transitions -->
# <div class="st-container">
# <!-- Fixed navbar -->
# <div class="navbar navbar-main navbar-primary navbar-fixed-top nav-background" role="navigation">
# <div class="container-fluid">
# <div class="navbar-header">
# <a class="toggle pull-left visible-xs" data-effect="st-effect-1" data-toggle="sidebar-menu" href="#sidebar-menu"><i class="fa fa-ellipsis-v"></i></a>
# <button class="navbar-toggle collapsed" data-target="#main-nav" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="toggle pull-right visible-xs" data-effect="st-effect-1" data-toggle="sidebar-menu" href="#sidebar-menu-right"><i class="fa fa-ticket"></i></a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse ng-scope" data-ng-controller="CustomNavMenuController" id="main-nav">
# <ul class="nav navbar-nav">
# <li class="active" data-ng-class="isActiveTab('esports') ? 'active' : ''">
# <a href="/esports/today">ESPORTS</a>
# </li>
# <li class="dropdown" data-dropdown="open" data-ng-class="{active : isActiveTab('results')}">
# <a class="dropdown-toggle user" href="#">
#                         RESULTS <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/results"> All Esports</a></li>
# <li><a href="/results-outright">Outright</a></li>
# </ul>
# </li>
# <li class="dropdown flags ng-scope" data-ng-class="languagesState" data-ng-controller="LanguageController">
# <!-- ngIf: language --><a aria-expanded="true" class="dropdown-toggle ng-scope" data-ng-click="accordionLanguages()" data-ng-if="language" data-toggle="dropdown" href="#">
# <img alt="United States" data-ng-src="/content/images/flags/Flag_of_the_United_States.svg" src="/content/images/flags/Flag_of_the_United_States.svg" style="width: 100%; height: auto; display: block; margin-left: auto; margin-right: auto;"/>
# <span class="caret"></span>
# </a><!-- end ngIf: language -->
# <!-- ngIf: language --><ul class="dropdown-menu min-width-none ng-scope" data-ng-if="language" role="menu">
# <!-- ngRepeat: language in languages --><li class="active text-center ng-scope" data-ng-click="setLanguage(language)" data-ng-repeat="language in languages">
# <a>
# <img alt="United States" data-ng-src="/content/images/flags/Flag_of_the_United_States.svg" src="/content/images/flags/Flag_of_the_United_States.svg" style="width: 100%; height: auto; display: block; margin-left: auto; margin-right: auto;"/>
# </a>
# </li><!-- end ngRepeat: language in languages --><li class="active text-center ng-scope" data-ng-click="setLanguage(language)" data-ng-repeat="language in languages">
# <a>
# <img alt="China" data-ng-src="/content/images/flags/Flag_of_China.svg" src="/content/images/flags/Flag_of_China.svg" style="width: 100%; height: auto; display: block; margin-left: auto; margin-right: auto;"/>
# </a>
# </li><!-- end ngRepeat: language in languages -->
# </ul><!-- end ngIf: language -->
# </li>
# </ul>
# <ul class="nav navbar-nav navbar-right ng-scope" data-ng-controller="AccountController">
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# </div>
# <!-- ngView:  --><div class="view ng-scope" data-ng-view=""><!-- Sidebar component with st-effect-1 (set on the toggle button within the navbar) -->
# <div class="sidebar left sidebar-size-2 sidebar-offset-0 sidebar-visible-desktop sidebar-visible-mobile sidebar-skin-dark sports-sidebar ng-scope" data-ng-controller="CustomLeftSidebarController" data-type="collapse" id="sidebar-menu" style="display:none">
# <div data-scrollable="">
# <div class="sidebar-block">
# <div class="padding-bottom-none text-center">
# <h4 class="margin-none ng-binding">17:51:24</h4><small class="ng-binding">December 8, 2017 (GMT-8)</small>
# </div>
# </div>
# <div class="sidebar-block sidebar-search ng-scope" data-ng-controller="CustomSearchController">
# <div class="padding-bottom-none form-group input-group">
# <input class="form-control ng-pristine ng-untouched ng-valid" data-ng-change="keywordChanged()" data-ng-model="keyword" placeholder="Team Search" type="text"/>
# <span class="input-group-btn">
# <button class="btn btn-primary" data-ng-click="keywordChanged()" type="button"><i class="fa fa-search"></i></button>
# </span>
# </div>
# </div>
# <ul class="sidebar-menu">
# <li class="">
# <a href="/esports/favorites">
# <i class="fa fa-fw fa-star"></i>
# <span>Favorites</span>
# </a>
# </li>
# <!-- ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/3683" title="Counter-Strike">
# <div class="sprite-icon-thumbnail icon-4 counter-strike undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">Counter-Strike</span>
# </a>
# <ul class="collapse" id="category_3683">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/3693" title="Dota 2">
# <div class="sprite-icon-thumbnail icon-1 dota-2 undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">Dota 2</span>
# </a>
# <ul class="collapse" id="category_3693">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/3578" title="League of Legends">
# <div class="sprite-icon-thumbnail icon-3 league-of-legends undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">League of Legends</span>
# </a>
# <ul class="collapse" id="category_3578">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/3598" title="Hearthstone">
# <div class="sprite-icon-thumbnail icon-8 hearthstone undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">Hearthstone</span>
# </a>
# <ul class="collapse" id="category_3598">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/3597" title="Heroes of the Storm">
# <div class="sprite-icon-thumbnail icon-7 heroes-of-the-storm undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">Heroes of the Storm</span>
# </a>
# <ul class="collapse" id="category_3597">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/6570" title="King of Glory">
# <div class="sprite-icon-thumbnail icon- king-of-glory undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">King of Glory</span>
# </a>
# <ul class="collapse" id="category_6570">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories --><li class="hasSubmenu ng-scope" data-ng-repeat="category in categories">
# <a class="collapsed" href="esports/program/0/6557" title="Rocket League">
# <div class="sprite-icon-thumbnail icon- rocket-league undefined" format-category-name="category.Name" format-name-to-class="" format-sporttype-name=""></div>
# <span class="ng-binding">Rocket League</span>
# </a>
# <ul class="collapse" id="category_6557">
# <!-- ngIf: category.LiveMatchesCount > 0 -->
# <!-- ngRepeat: tournament in category.tournaments -->
# </ul>
# </li><!-- end ngRepeat: category in categories -->
# </ul>
# </div>
# </div>
# <!-- Sidebar component with st-effect-1 (set on the toggle button within the navbar) -->
# <div class="sidebar right sidebar-size-3 sidebar-offset-0 sidebar-visible-desktop sidebar-visible-mobile sidebar-skin-dark ng-scope" data-ng-controller="CustomBetslipController" id="sidebar-menu-right">
# <div data-scrollable="">
# <div class="sidebar-block">
# <div class="">
# <div class="text-center">BET SLIP <!-- ngIf: selections.length > 0 --> </div>
# </div>
# </div>
# <!-- if no bet slip-->
# <!-- ngIf: selections.length == 0 && TicketItems.length == 0 --><div class="sidebar-block text-center ng-scope" data-ng-if="selections.length == 0 &amp;&amp; TicketItems.length == 0">
# <p>Your betslip is empty. </p>
# <small>Select events to place bets.</small>
# </div><!-- end ngIf: selections.length == 0 && TicketItems.length == 0 -->
# <!-- /end if no bet slip -->
# <!-- ngIf: selections.length > 0 || TicketItems.length > 0 -->
# </div>
# </div>
# <!-- content push wrapper -->
# <div class="st-pusher ng-scope" data-ng-init="setBodyClass(); setTitle('Early - BetOnline')" id="content">
# <!-- sidebar effects INSIDE of st-pusher: -->
# <!-- st-effect-3, st-effect-6, st-effect-7, st-effect-8, st-effect-14 -->
# <!-- this is the wrapper for the content -->
# <div class="st-content">
# <nav class="navbar navbar-subnav navbar-static-top margin-bottom-none ng-scope" data-ng-controller="MatchTypeNavigationController" role="navigation">
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div aria-expanded="false" class="" id="subnav" style="height: 1px;">
# <ul class="nav nav-justified">
# <li data-ng-class="isActiveTab('live') ? 'active' : ''">
# <a href="/esports/live">
# <i class="fa fa-fw fa-dot-circle-o"></i>
# <span class="hidden-xs">LIVE</span>
# </a>
# </li>
# <li data-ng-class="isActiveTab('today') ? 'active' : ''">
# <a href="/esports/today">
# <i class="fa fa-fw icon-calendar-1"></i>
# <span class="hidden-xs">TODAY</span>
# </a>
# </li>
# <li class="active" data-ng-class="isActiveTab('program') ? 'active' : ''">
# <a href="/esports/program">
# <i class="fa fa-fw icon-calendar-2"></i>
# <span class="hidden-xs">EARLY MARKETS</span>
# </a>
# </li>
# <li data-ng-class="isActiveTab('outrights') ? 'active' : ''">
# <a href="/esports/outrights">
# <i class="fa fa-fw fa-trophy"></i>
# <span class="hidden-xs">OUTRIGHT</span>
# </a>
# </li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </nav>
# <!-- extra div for emulating position:fixed of the menu -->
# <div class="st-content-inner">
# <!-- start outright calendar -->
# <!-- ngIf: !phrase --><div class="calendar-day-view top-subnav ng-scope" data-ng-if="!phrase"> <!--hide when search-->
# <div class="row seven-cols">
# <!-- ngRepeat: date in dates --><div class="col-xs-2 item ng-scope active" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 09</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Sat</span>
# </a>
# </div><!-- end ngRepeat: date in dates --><div class="col-xs-2 item ng-scope" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 10</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Sun</span>
# </a>
# </div><!-- end ngRepeat: date in dates --><div class="col-xs-2 item ng-scope" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 11</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Mon</span>
# </a>
# </div><!-- end ngRepeat: date in dates --><div class="col-xs-2 item ng-scope" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 12</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Tue</span>
# </a>
# </div><!-- end ngRepeat: date in dates --><div class="col-xs-2 item ng-scope" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 13</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Wed</span>
# </a>
# </div><!-- end ngRepeat: date in dates --><div class="col-xs-2 item ng-scope" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 14</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Thu</span>
# </a>
# </div><!-- end ngRepeat: date in dates --><div class="col-xs-2 item ng-scope" data-ng-class="getSelectedDateClass(date)" data-ng-click="setSelectedDate(date)" data-ng-repeat="date in dates">
# <a href="#">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><span class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'"> Dec 15</span><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <span class="date visible-md visible-lg ng-binding"> Fri</span>
# </a>
# </div><!-- end ngRepeat: date in dates -->
# </div>
# </div><!-- end ngIf: !phrase -->
# <!-- / end outright calendar -->
# <div class="container-fluid">
# <!-- insert content here -->
# <div class="panel-padded ng-scope" data-ng-controller="ViewSettingsController">
# <div class="row">
# <div class="col-xs-12 pull-right">
# <div class="dropdown pull-right" data-dropdown="open">
# <div class="btn-outline btn-xs dropdown-toggle ng-binding" data-ng-click="clickTimezone()" type="button">
#                     17:51:24 GMT-8
#                     <span class="caret"></span>
# </div>
# <ul class="dropdown-menu">
# <!-- ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">13:51:24 GMT-12</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">14:51:24 GMT-11</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">15:51:24 GMT-10</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">16:51:24 GMT-9</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">17:51:24 GMT-8</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">18:51:24 GMT-7</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">19:51:24 GMT-6</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">20:51:24 GMT-5 (EST)</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">21:51:24 GMT-4</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">22:51:24 GMT-3</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">23:51:24 GMT-2</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">00:51:24 GMT-1</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">01:51:24 GMT</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">02:51:24 GMT+1</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">03:51:24 GMT+2</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">04:51:24 GMT+3</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">05:51:24 GMT+4</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">06:51:24 GMT+5</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">07:51:24 GMT+6</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">08:51:24 GMT+7</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a class="ng-binding" href="#">09:51:24 GMT+8</a></li><!-- end ngRepeat: item in timezones --><li class="ng-scope" data-ng-click="setTimezone(item)" data-ng-repeat="item in timezones"><a  ...
# </ul>
# </div>
# <div class="dropdown pull-right capitalize" data-dropdown="open">
# <div class="btn-outline btn-xs dropdown-toggle ng-binding" data-ng-click="clickOddView()" type="button">
#                     Decimal
#                     <span class="caret"></span>
# </div>
# <ul class="dropdown-menu">
# <!-- ngRepeat: item in oddFormats --><li class="ng-scope" data-ng-click="setOddFormat(item.Value)" data-ng-repeat="item in oddFormats"><a class="ng-binding" href="#">American</a></li><!-- end ngRepeat: item in oddFormats --><li class="ng-scope" data-ng-click="setOddFormat(item.Value)" data-ng-repeat="item in oddFormats"><a class="ng-binding" href="#">Decimal</a></li><!-- end ngRepeat: item in oddFormats --><li class="ng-scope" data-ng-click="setOddFormat(item.Value)" data-ng-repeat="item in oddFormats"><a class="ng-binding" href="#">Fractional</a></li><!-- end ngRepeat: item in oddFormats --><li class="ng-scope" data-ng-click="setOddFormat(item.Value)" data-ng-repeat="item in oddFormats"><a class="ng-binding" href="#">Hong Kong</a></li><!-- end ngRepeat: item in oddFormats -->
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="loader loader-sport-block ng-hide" data-ng-show="matches == null || isLoadingMatches">Loading...</div>
# <!-- start sport -->
# <!-- ngRepeat: category in categories | orderBy : 'Rank' : true --><div class="panel panel-default panel-sport visible-lg ng-scope" data-ng-repeat="category in categories | orderBy : 'Rank' : true">
# <div class="row panel-heading border-none">
# <div class="col-xs-6 ng-binding">
# <div class="sprite-icon-thumbnail icon-4 counter-strike undefined" format-category-name="category.Name" format-name-to-class=""></div>Counter-Strike
#         </div>
# <div class="col-xs-1 col-sm-1 match-detail-th">
# <span class="visible-md visible-lg" title="Moneyline">1X2</span>
# </div>
# <div class="col-xs-1 col-sm-1 match-detail-th">
# <span class="visible-md visible-lg" title="Handicap">HDP </span>
# </div>
# <div class="col-xs-1 col-sm-1 match-detail-th">
# <span class="visible-md visible-lg" title="Map 1">Map 1 </span>
# </div>
# <div class="col-xs-1 col-sm-1 match-detail-th">
# <span class="visible-md visible-lg" title="Map 2">Map 2 </span>
# </div>
# <div class="col-xs-1 col-sm-1 match-detail-th">
# <span class="visible-md visible-lg" title="Map 3">Map 3 </span>
# </div>
# <div class="col-xs-1">
# </div>
# </div>
# <!-- start league -->
# <!-- ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><div class="panel panel-default margin-bottom-none panel-league ng-scope" data-ng-class="{'tournament-favorite' : tournament.IsFavorite }" data-ng-repeat="tournament in category.Tournaments | orderBy : 'Rank' : true">
# <div class="row">
# <div class="col-xs-10 col-sm-11 text-left panel-heading match-detail-league-name">
# <span class="ng-binding">
#                     ESL Pro League
#                 </span>
# </div>
# <div class="col-xs-2 col-sm-1 padding-none panel-heading" data-ng-class="{'match-detail-favorite' : tournament.IsFavorite }">
# <a data-ng-click="favoriteTournamentClick3(category.ID, tournament)" href="#">
# <i class="fa fa-fw fa-t fa-star"></i>
# </a>
# </div>
# </div>
# <!-- start match detail-->
# <!-- ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><div class="panel-match-detail ng-scope match-status-live" data-ng-class="{'favorite': match.IsFavorite, 'match-status-live': match.IsLive, suspended : match.IsSuspended, 'match-status-upcoming-live': isUpcoming(match)}" data-ng-repeat="match in tournament.Matches | filter : {IsFinished : 'false'}">
# <div class="row row-eq-height">
# <div class="col-xs-12">
# <!-- start teamA -->
# <div class="row row-eq-height match-detail-teamA-row">
# <div class="col-xs-2 col-sm-1 match-detail-time">
# <div class="absolute-center">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><small class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'">Dec 09 07:00</small><!-- end ngIf: selectedLanguage.code!='zh-CHS' --> <br/>
# </div>
# </div>
# <div class="col-xs-3 col-sm-5 text-left match-detail-team-name">
# <span class="vertical-align ng-binding">
#                                 FaZe
#                             </span>
# </div>
# <div class="col-xs-2 col-sm-1 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMoneyLine[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMoneyLine[0])" data-ng-if="match.PreviewOddsMoneyLine[0]">
#                                 1.31
#                             </span><!-- end ngIf: match.PreviewOddsMoneyLine[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsHandicap.Top1)">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsHandicap.Top1 --><div class="row odd ng-scope" data-ng-class="getOddClass(match.PreviewOddsHandicap.Top1)" data-ng-click="oddClick(match.PreviewOddsHandicap.Top1)" data-ng-if="match.PreviewOddsHandicap.Top1">
# <div class="col-xs-12 col-sm-6 font-unbold border-none ng-binding">
#                                     -1.5
#                                 </div>
# <div class="col-xs-12 col-sm-6 border-none ng-binding">
#                                     1.96
#                                 </div>
# </div><!-- end ngIf: match.PreviewOddsHandicap.Top1 -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap1[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap1[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap1[0])" data-ng-if="match.PreviewOddsMap1[0]">
#                                 1.54
#                             </span><!-- end ngIf: match.PreviewOddsMap1[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap2[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap2[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap2[0])" data-ng-if="match.PreviewOddsMap2[0]">
#                                 1.37
#                             </span><!-- end ngIf: match.PreviewOddsMap2[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap3[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap3[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap3[0])" data-ng-if="match.PreviewOddsMap3[0]">
#                                 1.46
#                             </span><!-- end ngIf: match.PreviewOddsMap3[0] -->
# </div>
# <div class="col-xs-1 match-detail-favorite event-link" data-ng-click="favoriteMatchClick(category.ID, tournament.ID, match)">
# <div class="absolute-center">
# <i class="fa fa-fw fa-star"></i>
# </div>
# </div>
# </div>
# <!-- //end teamA -->
# <!-- start teamB -->
# <div class="row row-eq-height match-detail-teamB-row">
# <div class="col-xs-2 col-sm-1">
# <!-- ngIf: match.StreamUrl --><a alt="Watch the game" class="popup ng-scope" data-ng-if="match.StreamUrl" ng-click="openInWindow(match.StreamUrl, '_blank')" title="Watch the game">
# <div class="event-link">
# <i class="fa fa-fw fa-video-camera"></i>
# </div>
# </a><!-- end ngIf: match.StreamUrl -->
# </div>
# <div class="col-xs-3 col-sm-5 text-left match-detail-team-name">
# <span class="vertical-align ng-binding">
#                                 Fnatic
#                             </span>
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMoneyLine[1] && match.PreviewOddsMoneyLine.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[1])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[1])" data-ng-if="match.PreviewOddsMoneyLine[1] &amp;&amp; match.PreviewOddsMoneyLine.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">3.41</span>
# </span><!-- end ngIf: match.PreviewOddsMoneyLine[1] && match.PreviewOddsMoneyLine.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine[2] && match.PreviewOddsMoneyLine.length > 2 -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsHandicap.Top2)">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <div class="row odd" data-ng-click="oddClick(match.PreviewOddsHandicap.Top2)">
# <div class="col-xs-12 col-sm-6 font-unbold border-none ng-binding">
#                                     +1.5
#                                 </div>
# <div class="col-xs-12 col-sm-6 border-none ng-binding">
#                                     1.80
#                                 </div>
# </div>
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMap1[1] && match.PreviewOddsMap1.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMap1[1])" data-ng-click="oddClick(match.PreviewOddsMap1[1])" data-ng-if="match.PreviewOddsMap1[1] &amp;&amp; match.PreviewOddsMap1.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">2.43</span>
# </span><!-- end ngIf: match.PreviewOddsMap1[1] && match.PreviewOddsMap1.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMap1[2] && match.PreviewOddsMap1.length > 2 -->
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMap2[1] && match.PreviewOddsMap2.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMap2[1])" data-ng-click="oddClick(match.PreviewOddsMap2[1])" data-ng-if="match.PreviewOddsMap2[1] &amp;&amp; match.PreviewOddsMap2.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">2.86</span>
# </span><!-- end ngIf: match.PreviewOddsMap2[1] && match.PreviewOddsMap2.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMap2[2] && match.PreviewOddsMap2.length > 2 -->
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMap3[1] && match.PreviewOddsMap3.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMap3[1])" data-ng-click="oddClick(match.PreviewOddsMap3[1])" data-ng-if="match.PreviewOddsMap3[1] &amp;&amp; match.PreviewOddsMap3.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">2.69</span>
# </span><!-- end ngIf: match.PreviewOddsMap3[1] && match.PreviewOddsMap3.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMap3[2] && match.PreviewOddsMap3.length > 2 -->
# </div>
# <div class="col-xs-1 match-detail-markets event-link">
# <a data-ng-click="showMarketsClick(match)" href="#" title="Other Markets">
# <div class="absolute-center">
# <span class="badge ng-binding" data-ng-show="match.moreMarketsCount &gt; 0">+15</span>
# </div>
# </a>
# </div>
# </div>
# <!-- //end teamB -->
# <!-- start draw -->
# <!-- ngIf: match.PreviewOddsMoneyLine[2] && match.PreviewOddsMoneyLine.length > 2 -->
# <!-- //end draw -->
# </div>
# </div>
# <!-- ngIf: match.isShowAllMarkets -->
# </div><!-- end ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><div class="panel-match-detail ng-scope match-status-live" data-ng-class="{'favorite': match.IsFavorite, 'match-status-live': match.IsLive, suspended : match.IsSuspended, 'match-status-upcoming-live': isUpcoming(match)}" data-ng-repeat="match in tournament.Matches | filter : {IsFinished : 'false'}">
# <div class="row row-eq-height">
# <div class="col-xs-12">
# <!-- start teamA -->
# <div class="row row-eq-height match-detail-teamA-row">
# <div class="col-xs-2 col-sm-1 match-detail-time">
# <div class="absolute-center">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><small class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'">Dec 09 10:50</small><!-- end ngIf: selectedLanguage.code!='zh-CHS' --> <br/>
# </div>
# </div>
# <div class="col-xs-3 col-sm-5 text-left match-detail-team-name">
# <span class="vertical-align ng-binding">
#                                 SK
#                             </span>
# </div>
# <div class="col-xs-2 col-sm-1 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMoneyLine[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMoneyLine[0])" data-ng-if="match.PreviewOddsMoneyLine[0]">
#                                 1.17
#                             </span><!-- end ngIf: match.PreviewOddsMoneyLine[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsHandicap.Top1)">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsHandicap.Top1 --><div class="row odd ng-scope" data-ng-class="getOddClass(match.PreviewOddsHandicap.Top1)" data-ng-click="oddClick(match.PreviewOddsHandicap.Top1)" data-ng-if="match.PreviewOddsHandicap.Top1">
# <div class="col-xs-12 col-sm-6 font-unbold border-none ng-binding">
#                                     -1.5
#                                 </div>
# <div class="col-xs-12 col-sm-6 border-none ng-binding">
#                                     1.60
#                                 </div>
# </div><!-- end ngIf: match.PreviewOddsHandicap.Top1 -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap1[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap1[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap1[0])" data-ng-if="match.PreviewOddsMap1[0]">
#                                 1.36
#                             </span><!-- end ngIf: match.PreviewOddsMap1[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap2[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap2[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap2[0])" data-ng-if="match.PreviewOddsMap2[0]">
#                                 1.26
#                             </span><!-- end ngIf: match.PreviewOddsMap2[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap3[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap3[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap3[0])" data-ng-if="match.PreviewOddsMap3[0]">
#                                 1.30
#                             </span><!-- end ngIf: match.PreviewOddsMap3[0] -->
# </div>
# <div class="col-xs-1 match-detail-favorite event-link" data-ng-click="favoriteMatchClick(category.ID, tournament.ID, match)">
# <div class="absolute-center">
# <i class="fa fa-fw fa-star"></i>
# </div>
# </div>
# </div>
# <!-- //end teamA -->
# <!-- start teamB -->
# <div class="row row-eq-height match-detail-teamB-row">
# <div class="col-xs-2 col-sm-1">
# <!-- ngIf: match.StreamUrl --><a alt="Watch the game" class="popup ng-scope" data-ng-if="match.StreamUrl" ng-click="openInWindow(match.StreamUrl, '_blank')" title="Watch the game">
# <div class="event-link">
# <i class="fa fa-fw fa-video-camera"></i>
# </div>
# </a><!-- end ngIf: match.StreamUrl -->
# </div>
# <div class="col-xs-3 col-sm-5 text-left match-detail-team-name">
# <span class="vertical-align ng-binding">
#                                 Misfits
#                             </span>
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMoneyLine[1] && match.PreviewOddsMoneyLine.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[1])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[1])" data-ng-if="match.PreviewOddsMoneyLine[1] &amp;&amp; match.PreviewOddsMoneyLine.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">4.92</span>
# </span><!-- end ngIf: match.PreviewOddsMoneyLine[1] && match.PreviewOddsMoneyLine.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine[2] && match.PreviewOddsMoneyLine.length > 2 -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsHandicap.Top2)">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <div class="row odd" data-ng-click="oddClick(match.PreviewOddsHandicap.Top2)">
# <div class="col-xs-12 col-sm-6 font-unbold border-none ng-binding">
#                                     +1.5
#                                 </div>
# <div class="col-xs-12 col-sm-6 border-none ng-binding">
#                                     2.20
#                                 </div>
# </div>
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMap1[1] && match.PreviewOddsMap1.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMap1[1])" data-ng-click="oddClick(match.PreviewOddsMap1[1])" data-ng-if="match.PreviewOddsMap1[1] &amp;&amp; match.PreviewOddsMap1.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">3.07</span>
# </span><!-- end ngIf: match.PreviewOddsMap1[1] && match.PreviewOddsMap1.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMap1[2] && match.PreviewOddsMap1.length > 2 -->
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMap2[1] && match.PreviewOddsMap2.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMap2[1])" data-ng-click="oddClick(match.PreviewOddsMap2[1])" data-ng-if="match.PreviewOddsMap2[1] &amp;&amp; match.PreviewOddsMap2.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">3.79</span>
# </span><!-- end ngIf: match.PreviewOddsMap2[1] && match.PreviewOddsMap2.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMap2[2] && match.PreviewOddsMap2.length > 2 -->
# </div>
# <div class="col-xs-2 col-sm-1 event-link">
# <!-- ngIf: match.PreviewOddsMap3[1] && match.PreviewOddsMap3.length <= 2 --><span class="absolute-center ng-scope" data-ng-class="getOddClasses(match.PreviewOddsMap3[1])" data-ng-click="oddClick(match.PreviewOddsMap3[1])" data-ng-if="match.PreviewOddsMap3[1] &amp;&amp; match.PreviewOddsMap3.length &lt;= 2">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <span class="odd ng-binding">3.48</span>
# </span><!-- end ngIf: match.PreviewOddsMap3[1] && match.PreviewOddsMap3.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMap3[2] && match.PreviewOddsMap3.length > 2 -->
# </div>
# <div class="col-xs-1 match-detail-markets event-link">
# <a data-ng-click="showMarketsClick(match)" href="#" title="Other Markets">
# <div class="absolute-center">
# <span class="badge ng-binding" data-ng-show="match.moreMarketsCount &gt; 0">+12</span>
# </div>
# </a>
# </div>
# </div>
# <!-- //end teamB -->
# <!-- start draw -->
# <!-- ngIf: match.PreviewOddsMoneyLine[2] && match.PreviewOddsMoneyLine.length > 2 -->
# <!-- //end draw -->
# </div>
# </div>
# <!-- ngIf: match.isShowAllMarkets -->
# </div><!-- end ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><!-- / end match detail-->
# </div><!-- end ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><div class="panel panel-default margin-bottom-none panel-league ng-scope" data-ng-class="{'tournament-favorite' : tournament.IsFavorite }" data-ng-repeat="tournament in category.Tournaments | orderBy : 'Rank' : true">
# <div class="row">
# <div class="col-xs-10 col-sm-11 text-left panel-heading match-detail-league-name">
# <span class="ng-binding">
#                     Gfinity Elite Series
#                 </span>
# </div>
# <div class="col-xs-2 col-sm-1 padding-none panel-heading" data-ng-class="{'match-detail-favorite' : tournament.IsFavorite }">
# <a data-ng-click="favoriteTournamentClick3(category.ID, tournament)" href="#">
# <i class="fa fa-fw fa-t fa-star"></i>
# </a>
# </div>
# </div>
# <!-- start match detail-->
# <!-- ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><div class="panel-match-detail ng-scope" data-ng-class="{'favorite': match.IsFavorite, 'match-status-live': match.IsLive, suspended : match.IsSuspended, 'match-status-upcoming-live': isUpcoming(match)}" data-ng-repeat="match in tournament.Matches | filter : {IsFinished : 'false'}">
# <div class="row row-eq-height">
# <div class="col-xs-12">
# <!-- start teamA -->
# <div class="row row-eq-height match-detail-teamA-row">
# <div class="col-xs-2 col-sm-1 match-detail-time">
# <div class="absolute-center">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><small class="ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'">Dec 09 06:15</small><!-- end ngIf: selectedLanguage.code!='zh-CHS' --> <br/>
# </div>
# </div>
# <div class="col-xs-3 col-sm-5 text-left match-detail-team-name">
# <span class="vertical-align ng-binding">
#                                 EnVyUs Academy
#                             </span>
# </div>
# <div class="col-xs-2 col-sm-1 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMoneyLine[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMoneyLine[0])" data-ng-if="match.PreviewOddsMoneyLine[0]">
#                                 1.40
#                             </span><!-- end ngIf: match.PreviewOddsMoneyLine[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsHandicap.Top1)">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsHandicap.Top1 -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap1[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap1[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap1[0])" data-ng-if="match.PreviewOddsMap1[0]">
#                                 1.50
#                             </span><!-- end ngIf: match.PreviewOddsMap1[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap2[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap2[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap2[0])" data-ng-if="match.PreviewOddsMap2[0]">
#                                 1.50
#                             </span><!-- end ngIf: match.PreviewOddsMap2[0] -->
# </div>
# <div class="col-xs-2 col-sm-1 double-line event-link" data-ng-class="getOddClasses(match.PreviewOddsMap3[0])">
# <span class="absolute-center suspended-img"> <i class="fa fa-lock fa-1"></i> </span>
# <!-- ngIf: match.PreviewOddsMap3[0] --><span class="absolute-center odd ng-binding ng-scope" data-ng-click="oddClick(match.PreviewOddsMap3[0])" data-ng-if="match.PreviewOddsMap3[0]">
#                                 1.50
#                             </span><!-- end ngIf: match.PreviewOddsMap3[0] -->
# </div>
# <div class="col-xs-1 match-detail-favorite event-link" data-ng-click="favoriteMatchClick(category.ID, tournament.ID, match)">
# <div class="absolute-center">
# ...
# <a data-ng-click="favoriteTournamentClick3(category.ID, tournament)" href="#">
# <i class="fa fa-fw fa-t fa-star"></i>
# </a>
# </div>
# </div>
# <!-- ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><div class="panel-match-detail text-indent15 ng-scope" data-ng-class="{'favorite': match.IsFavorite, 'match-status-live': match.IsLive, suspended : match.IsSuspended}" data-ng-repeat="match in tournament.Matches | filter : {IsFinished : 'false'}">
# <!-- start time -->
# <a data-ng-click="showMarketsClick(match)" title="Other Markets">
# <div class="row match-detail-time">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><div class="col-xs-9 ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'">
#                         Dec 09 02:00
#                     </div><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <div class="col-xs-3 text-center">
# <span class="badge ng-binding" data-ng-show="match.moreMarketsCount &gt; 0">+17</span>
# </div>
# </div>
# </a>
# <!-- //end time -->
# <!-- start money line -->
# <!-- ngIf: match.PreviewOddsMoneyLine --><div class="ng-scope" data-ng-if="match.PreviewOddsMoneyLine">
# <div class="row">
# <div class="col-xs-12 market-title">
#                         Money Line
#                     </div>
# </div>
# <div class="row" data-ng-class="match.IsSuspended || market.IsSuspended ? 'suspended' : ''">
# <div class="col-xs-6 border-right">
# <strong class="ng-binding">KSV Black</strong>
# </div>
# <div class="col-xs-6 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[0])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[0])">
# <span class="odd ng-binding">
#                             1.29
#                         </span>
# </div>
# </div>
# <!-- ngIf: match.PreviewOddsMoneyLine.length <= 2 --><div class="row ng-scope" data-ng-class="match.IsSuspended || market.IsSuspended ? 'suspended' : ''" data-ng-if="match.PreviewOddsMoneyLine.length &lt;= 2">
# <div class="col-xs-6 border-right">
# <strong class="ng-binding">Team Ballistix</strong>
# </div>
# <div class="col-xs-6 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[1])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[1])">
# <span class="odd ng-binding">
#                             3.25
#                         </span>
# </div>
# </div><!-- end ngIf: match.PreviewOddsMoneyLine.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine.length > 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine.length > 2 -->
# </div><!-- end ngIf: match.PreviewOddsMoneyLine -->
# <!-- end money line -->
# <!-- start other markets -->
# <!-- ngIf: match.isShowAllMarkets -->
# </div><!-- end ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} -->
# </div><!-- end ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><!-- / end league -->
# </div><!-- end ngRepeat: category in categories | orderBy : 'Rank' : true --><div class="panel panel-default panel-sport hidden-lg ng-scope" data-ng-repeat="category in categories | orderBy : 'Rank' : true">
# <div class="row panel-heading border-none">
# <div class="col-xs-5 ng-binding">
# <div class="sprite-icon-thumbnail icon-48 king-of-glory undefined" format-category-name="category.Name" format-name-to-class=""></div> King of Glory
#         </div>
# </div>
# <!-- start league -->
# <!-- ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><div class="panel panel-default margin-bottom-none panel-league ng-scope" data-ng-class="{'tournament-favorite' : tournament.IsFavorite }" data-ng-repeat="tournament in category.Tournaments | orderBy : 'Rank' : true">
# <div class="row">
# <div class="col-xs-10 col-sm-11 text-left panel-heading match-detail-league-name">
# <span class="ng-binding">
#                     King Pro League
#                 </span>
# </div>
# <div class="col-xs-2 col-sm-1 padding-none panel-heading" data-ng-class="{'match-detail-favorite' : tournament.IsFavorite }">
# <a data-ng-click="favoriteTournamentClick3(category.ID, tournament)" href="#">
# <i class="fa fa-fw fa-t fa-star"></i>
# </a>
# </div>
# </div>
# <!-- ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><div class="panel-match-detail text-indent15 ng-scope" data-ng-class="{'favorite': match.IsFavorite, 'match-status-live': match.IsLive, suspended : match.IsSuspended}" data-ng-repeat="match in tournament.Matches | filter : {IsFinished : 'false'}">
# <!-- start time -->
# <a data-ng-click="showMarketsClick(match)" title="Other Markets">
# <div class="row match-detail-time">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><div class="col-xs-9 ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'">
#                         Dec 09 03:00
#                     </div><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <div class="col-xs-3 text-center">
# <span class="badge ng-binding" data-ng-show="match.moreMarketsCount &gt; 0">+44</span>
# </div>
# </div>
# </a>
# <!-- //end time -->
# <!-- start money line -->
# <!-- ngIf: match.PreviewOddsMoneyLine --><div class="ng-scope" data-ng-if="match.PreviewOddsMoneyLine">
# <div class="row">
# <div class="col-xs-12 market-title">
#                         Money Line
#                     </div>
# </div>
# <div class="row" data-ng-class="match.IsSuspended || market.IsSuspended ? 'suspended' : ''">
# <div class="col-xs-6 border-right">
# <strong class="ng-binding">JC Gaming</strong>
# </div>
# <div class="col-xs-6 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[0])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[0])">
# <span class="odd ng-binding">
#                             1.66
#                         </span>
# </div>
# </div>
# <!-- ngIf: match.PreviewOddsMoneyLine.length <= 2 --><div class="row ng-scope" data-ng-class="match.IsSuspended || market.IsSuspended ? 'suspended' : ''" data-ng-if="match.PreviewOddsMoneyLine.length &lt;= 2">
# <div class="col-xs-6 border-right">
# <strong class="ng-binding">eStar Gaming</strong>
# </div>
# <div class="col-xs-6 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[1])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[1])">
# <span class="odd ng-binding">
#                             2.11
#                         </span>
# </div>
# </div><!-- end ngIf: match.PreviewOddsMoneyLine.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine.length > 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine.length > 2 -->
# </div><!-- end ngIf: match.PreviewOddsMoneyLine -->
# <!-- end money line -->
# <!-- start other markets -->
# <!-- ngIf: match.isShowAllMarkets -->
# </div><!-- end ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} -->
# </div><!-- end ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><!-- / end league -->
# </div><!-- end ngRepeat: category in categories | orderBy : 'Rank' : true --><div class="panel panel-default panel-sport hidden-lg ng-scope" data-ng-repeat="category in categories | orderBy : 'Rank' : true">
# <div class="row panel-heading border-none">
# <div class="col-xs-5 ng-binding">
# <div class="sprite-icon-thumbnail icon-48 rocket-league undefined" format-category-name="category.Name" format-name-to-class=""></div> Rocket League
#         </div>
# </div>
# <!-- start league -->
# <!-- ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><div class="panel panel-default margin-bottom-none panel-league ng-scope" data-ng-class="{'tournament-favorite' : tournament.IsFavorite }" data-ng-repeat="tournament in category.Tournaments | orderBy : 'Rank' : true">
# <div class="row">
# <div class="col-xs-10 col-sm-11 text-left panel-heading match-detail-league-name">
# <span class="ng-binding">
#                     Gfinity Elite Series
#                 </span>
# </div>
# <div class="col-xs-2 col-sm-1 padding-none panel-heading" data-ng-class="{'match-detail-favorite' : tournament.IsFavorite }">
# <a data-ng-click="favoriteTournamentClick3(category.ID, tournament)" href="#">
# <i class="fa fa-fw fa-t fa-star"></i>
# </a>
# </div>
# </div>
# <!-- ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} --><div class="panel-match-detail text-indent15 ng-scope" data-ng-class="{'favorite': match.IsFavorite, 'match-status-live': match.IsLive, suspended : match.IsSuspended}" data-ng-repeat="match in tournament.Matches | filter : {IsFinished : 'false'}">
# <!-- start time -->
# <a data-ng-click="showMarketsClick(match)" title="Other Markets">
# <div class="row match-detail-time">
# <!-- ngIf: selectedLanguage.code=='zh-CHS' -->
# <!-- ngIf: selectedLanguage.code!='zh-CHS' --><div class="col-xs-9 ng-binding ng-scope" data-ng-if="selectedLanguage.code!='zh-CHS'">
#                         Dec 09 02:00
#                     </div><!-- end ngIf: selectedLanguage.code!='zh-CHS' -->
# <div class="col-xs-3 text-center">
# <span class="badge ng-binding ng-hide" data-ng-show="match.moreMarketsCount &gt; 0">+0</span>
# </div>
# </div>
# </a>
# <!-- //end time -->
# <!-- start money line -->
# <!-- ngIf: match.PreviewOddsMoneyLine --><div class="ng-scope" data-ng-if="match.PreviewOddsMoneyLine">
# <div class="row">
# <div class="col-xs-12 market-title">
#                         Money Line
#                     </div>
# </div>
# <div class="row" data-ng-class="match.IsSuspended || market.IsSuspended ? 'suspended' : ''">
# <div class="col-xs-6 border-right">
# <strong class="ng-binding">Reason</strong>
# </div>
# <div class="col-xs-6 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[0])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[0])">
# <span class="odd ng-binding">
#                             1.37
#                         </span>
# </div>
# </div>
# <!-- ngIf: match.PreviewOddsMoneyLine.length <= 2 --><div class="row ng-scope" data-ng-class="match.IsSuspended || market.IsSuspended ? 'suspended' : ''" data-ng-if="match.PreviewOddsMoneyLine.length &lt;= 2">
# <div class="col-xs-6 border-right">
# <strong class="ng-binding">Endpoint</strong>
# </div>
# <div class="col-xs-6 event-link" data-ng-class="getOddClasses(match.PreviewOddsMoneyLine[1])" data-ng-click="oddClick(match.PreviewOddsMoneyLine[1])">
# <span class="odd ng-binding">
#                             2.90
#                         </span>
# </div>
# </div><!-- end ngIf: match.PreviewOddsMoneyLine.length <= 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine.length > 2 -->
# <!-- ngIf: match.PreviewOddsMoneyLine.length > 2 -->
# </div><!-- end ngIf: match.PreviewOddsMoneyLine -->
# <!-- end money line -->
# <!-- start other markets -->
# <!-- ngIf: match.isShowAllMarkets -->
# </div><!-- end ngRepeat: match in tournament.Matches | filter : {IsFinished : 'false'} -->
# </div><!-- end ngRepeat: tournament in category.Tournaments | orderBy : 'Rank' : true --><!-- / end league -->
# </div><!-- end ngRepeat: category in categories | orderBy : 'Rank' : true --><!-- / end sport here -->
# <!-- / end content here -->
# </div>
# </div>
# <!-- /st-content-inner -->
# </div>
# <!-- /st-content -->
# </div>
# </div>
# </div>
# <!-- /st-container -->
# <!-- start match result modal -->
# <div class="modal modal-match-result fade modal-sidebets" data-backdrop="static" data-keyboard="false">
# <div class="modal-dialog">
# <div class="v-cell">
# <!-- ngIf: showMatchResultModalMatchId -->
# </div>
# </div>
# </div>
# <!-- start bet error modal -->
# <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade modal-default modal-bet-error" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content modal-sm">
# <!-- Modal Header -->
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# <span class="sr-only">Close</span>
# </button>
# </div>
# <!-- Modal Body -->
# <div class="modal-body text-center">
# <i class="fa fa-fw fa-warning fa-5x"></i>
# <p class="modal-error-message">This is a message</p>
# </div>
# <!-- Modal Footer -->
# <div class="modal-footer padding-none">
# <button class="btn btn-primary" data-dismiss="modal" type="button">
#                     OK
#                 </button>
# </div>
# </div>
# </div>
# </div>
# <!-- end bet error modal -->
# <!-- start login modal -->
# <div aria-hidden="true" class="modal fade modal-default modal-login" role="dialog" tabindex="-1">
# <div class="modal-dialog ng-scope" data-ng-controller="CustomAuthorizationController">
# <div class="modal-content modal-sm">
# <!-- Modal Header -->
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# <span class="sr-only">Close</span>
# </button>
# <h4 class="modal-title" id="myModalLabel">
#                     Login
#                 </h4>
# </div>
# <form class="form-horizontal ng-pristine ng-valid">
# <!-- Modal Body -->
# <div class="modal-body ng-binding">
# <div class="form-group">
# <div class="col-sm-12">
# <div class="input-group">
# <span class="input-group-addon"><i class="fa fa-user"></i></span>
# <input autocomplete="off" class="form-control login-username ng-pristine ng-untouched ng-valid" data-ng-model="loginModel.Login" name="login_username" placeholder="Username" tabindex="1" type="text"/>
# </div>
# </div>
# </div>
# <div class="form-group">
# <div class="col-sm-12">
# <div class="input-group">
# <span class="input-group-addon"><i class="fa fa-lock"></i></span>
# <input autocomplete="off" class="form-control ng-pristine ng-untouched ng-valid" data-ng-model="loginModel.Password" name="login_password" placeholder="Password" tabindex="2" type="password"/>
# </div>
# </div>
# </div>
# <div class="form-group">
# <div class="col-sm-12" id="captcha">
# <div class="input-group ng-hide" ng-show="isCaptchaAvaible()">
# <span class="input-group-addon"><i class="fa fa-warning"></i></span>
# <input autocomplete="off" class="form-control ng-pristine ng-untouched ng-valid" data-ng-model="loginModel.CaptchaResponse" name="login_captchaResponse" placeholder="Captcha text" type="text"/>
# </div>
# <!-- ngIf: isCaptchaAvaible() -->
# </div>
# </div>
# <div class="row">
# <div class="col-sm-6">
# <a data-ng-click="openModal('modal-registration')" href="#">
# <small> Create an account </small>
# </a>
# </div>
# <div class="col-sm-6">
# <a data-ng-click="openModal('modal-lost-password')" href="#">
# <small> Forgot password? </small>
# </a>
# </div>
# </div>
# </div>
# <!-- Modal Footer -->
# <div class="modal-footer padding-none">
# <input autofocus="" class="btn btn-primary" data-dismiss="modal" data-ng-click="loginClick(loginModel)" tabindex="4" type="submit" value="SIGN IN"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# <!-- end login modal -->
# <!-- start sign up modal -->
# <!-- ngIf: isRegistrationModalOpen -->
# <!-- end sign up modal --><!-- start reset password modal -->
# <!-- ngIf: isLostPasswordModalOpen -->
# <!-- end login modal -->
# <script>
#         window.registrationValidationConstants = {
#             userNameLength: 'Username must be between 6 and 12 characters.',
#             userNameCharecters: 'Username must contain only numbers and letters.',
#             passwordLenght: 'Password must be between 6 and 12 characters.',
#             passwordAlphanumeric: 'Password must contain only numbers and letters.',
#             passwordConfirm: 'Both passwords are not the same.',
#             nameCharecters: 'Name must contain only letters.',
#             phoneNumber: 'Phone can only contain numbers.',
#             email: 'Should contain @ sign.',
#             invalidString: 'input must be a valid string.',
#             required: 'This field is required.',
#             propertyNotFound: 'Property does not exist.',
#             usernameLeastOneLetterAndNumber: 'Username must contain at least one letter and number.',
#             passwordLeastOneLetterAndNumber: 'Password must contain at least one letter and number.'
#         }
#     </script>
# <!--CDN scripts-->
# <script src="https://webapi.ultraplay.net/js"></script>
# <script src="https://webapi.ultraplay.net/js/profile"></script>
# <script src="https://webapi.ultraplay.net/js/register"></script>
# <!--Local scripts-->
# <script src="/bundles/scripts/vendor?v=TZNAw_3CRX8SZgcBa50fsdH18JuFH8KokeWh9kWPGX41"></script>
# <script src="/bundles/content/js?v=6ZMWMHGGJiTg8jTAcY9imJeMcWhzI1OuAfOuM7JvNdk1"></script>
# </body>

# %%
# get leagues
leagueList = soup.find_all('div', {'class': 'panel panel-default margin-bottom-none panel-league ng-scope'})

#print(leagueList[1])

for league in leagueList:
    if league is not None:
        leagueName = league.find('div', {'class': 'col-xs-10 col-sm-11 text-left panel-heading match-detail-league-name'})
        print(leagueName.text.strip())
# Out:
# ROG Masters 2017
# MDL Macau
# All Stars 2017
# Overwatch League Season 1
# GCWC 2017
# Gold Club Championship
# ROG Masters 2017
# MDL Macau
# All Stars 2017
# Overwatch League Season 1
# GCWC 2017
# Gold Club Championship

# %%
# get 1x2 value
#games = soup.find_all('div', {'class': 'panel-match-detail'})
#print(games[1])

# %%
games = soup.find_all('div', {'class': 'panel-match-detail'})

todayScores = pd.DataFrame(columns=['MatchID','Date','TeamID','Team','Moneyline','HDP','Map1','Map2','Map3'])
i = 0
for game in games:
    teamA = game.find('div', {'class':'match-detail-teamA-row'})
    teamB = game.find('div', {'class':'match-detail-teamB-row'})
    if teamA is not None:
        teamName1 = teamA.find('div', {'class': 'match-detail-team-name'}).text.strip()
        teamName2 = teamB.find('div', {'class': 'match-detail-team-name'}).text.strip()
        Odds1 = teamA.find_all('div', {'class': 'col-xs-2 col-sm-1 event-link'})
        Odds2 = teamB.find_all('div', {'class': 'col-xs-2 col-sm-1 event-link'})
    
        ML1 = Odds1[0].text.strip()
        ML2 = Odds2[0].text.strip()

        # create dataframe to hold entry
        pdGame = pd.DataFrame([[i, 0, 0, teamName1, ML1, 0, 0, 0, 0],
                               [i, 0, 0, teamName2, ML2, 0, 0, 0, 0]],
                              columns=['MatchID','Date','TeamID','Team','Moneyline','HDP','Map1','Map2','Map3'])
        #print(pdGame)
        todayScores = todayScores.append(pdGame)
        i = i+1
print(todayScores)
# Out:
#   MatchID Date TeamID              Team Moneyline HDP Map1 Map2 Map3
# 0       0    0      0         GrayHound      1.98   0    0    0    0
# 1       0    0      0             TyLoo      1.76   0    0    0    0
# 0       1    0      0            Gambit      1.24   0    0    0    0
# 1       1    0      0     Vega Squadron      3.81   0    0    0    0
# 0       2    0      0          Infamous      4.42   0    0    0    0
# 1       2    0      0               LGD      1.20   0    0    0    0
# 0       3    0      0                OG      1.64   0    0    0    0
# 1       3    0      0        TnC Gaming      2.22   0    0    0    0
# 0       4    0      0             Na`Vi      2.10   0    0    0    0
# 1       4    0      0        Virtus.pro      1.71   0    0    0    0
# 0       5    0      0               LGD      1.40   0    0    0    0
# 1       5    0      0         VGJ.Storm      2.90   0    0    0    0
# 0       6    0      0            LGD.FY      1.58   0    0    0    0
# 1       6    0      0        TnC Gaming      2.34   0    0    0    0
# 0       7    0      0          Infamous      4.72   0    0    0    0
# 1       7    0      0                OG      1.18   0    0    0    0
# 0       8    0      0             EHOME      2.47   0    0    0    0
# 1       8    0      0        Virtus.pro      1.52   0    0    0    0
# 0       9    0      0             Na`Vi      1.85   0    0    0    0
# 1       9    0      0        TnC Gaming      1.93   0    0    0    0
# 0      10    0      0          Infamous      4.46   0    0    0    0
# 1      10    0      0            LGD.FY      1.20   0    0    0    0
# 0      11    0      0                OG      1.30   0    0    0    0
# 1      11    0      0         VGJ.Storm      3.46   0    0    0    0
# 0      12    0      0   Korea All-Stars      1.11   0    0    0    0
# 1      12    0      0  Turkey All-Stars      5.73   0    0    0    0
# 0      13    0      0   China All-Stars      1.19   0    0    0    0
# 1      13    0      0  Brazil All-Stars      4.25   0    0    0    0
# 0      14    0      0              Pray      1.38   0    0    0    0
# 1      14    0      0          SwordArT      2.84   0    0    0    0
# 0      15    0      0             Faker      1.56   0    0    0    0
# 1      15    0      0          Bjergsen      2.30   0    0    0    0
# 0      16    0      0           Rekkles      1.51   0    0    0    0
# 1      16    0      0           Zeitnot      2.42   0    0    0    0
# 0      17    0      0              Jisu      2.08   0    0    0    0
# 1      17    0      0             Meiko      1.68   0    0    0    0
# 0      18    0      0               Uzi      1.32   0    0    0    0
# 1      18    0      0              brTT      3.15   0    0    0    0
# 0      19    0      0     Seoul Dynasty      1.17   0    0    0    0
# 1      19    0      0   Houston Outlaws      4.93   0    0    0    0
# 0      20    0      0  Shanghai Dragons      1.91   0    0    0    0
# 1      20    0      0   Boston Uprising      1.87   0    0    0    0
# 0      21    0      0          Alliance      1.68   0    0    0    0
# 1      21    0      0        Planet Odd      2.08   0    0    0    0
# 0      22    0      0          Dignitas      1.70   0    0    0    0
# 1      22    0      0            Fnatic      2.03   0    0    0    0

# %%
games2 = soup2.find_all('div', {'class': 'panel-match-detail'})

tomorrowScores = pd.DataFrame(columns=['MatchID','Date','TeamID','Team','Moneyline','HDP','Map1','Map2','Map3'])
i = 0
for game in games2:
    teamA = game.find('div', {'class':'match-detail-teamA-row'})
    teamB = game.find('div', {'class':'match-detail-teamB-row'})
    if teamA is not None:
        teamName1 = teamA.find('div', {'class': 'match-detail-team-name'}).text.strip()
        teamName2 = teamB.find('div', {'class': 'match-detail-team-name'}).text.strip()
        Odds1 = teamA.find_all('div', {'class': 'col-xs-2 col-sm-1 event-link'})
        Odds2 = teamB.find_all('div', {'class': 'col-xs-2 col-sm-1 event-link'})
        
        print(game.get('class'))
        print(teamName1)
        #print(Odds1)
        
        ML1 = 0
        ML2 = 0
        
        if 'suspended' not in (game.get('class')):
            ML1 = Odds1[0].text.strip()
            ML2 = Odds2[0].text.strip()

        # create dataframe to hold entry
        pdGame = pd.DataFrame([[i, 0, 0, teamName1, ML1, 0, 0, 0, 0],
                               [i, 0, 0, teamName2, ML2, 0, 0, 0, 0]],
                              columns=['MatchID','Date','TeamID','Team','Moneyline','HDP','Map1','Map2','Map3'])
        #print(pdGame)
        todayScores = todayScores.append(pdGame)
        i = i+1
print(todayScores)
# Out:
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# FaZe
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# SK
# ['panel-match-detail', 'ng-scope']
# EnVyUs Academy
# ['panel-match-detail', 'ng-scope']
# spray'n'pray
# ['panel-match-detail', 'ng-scope']
# GoodJob
# ['panel-match-detail', 'ng-scope']
# OpTic Gaming
# ['panel-match-detail', 'ng-scope']
# Team Empire
# ['panel-match-detail', 'ng-scope', 'match-status-live', 'suspended']
# EHOME
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# TnC Gaming
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# Infamous
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# LGD.FY
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# LGD
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# EHOME
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# Infamous
# ['panel-match-detail', 'ng-scope', 'match-status-live']
# Na`Vi
# ['panel-match-detail', 'ng-scope']
# INTZ
# ['panel-match-detail', 'ng-scope']
# Operation Kino
# ['panel-match-detail', 'ng-scope']
# Royal Never Give Up
# ['panel-match-detail', 'ng-scope']
# KSV Black
# ['panel-match-detail', 'ng-scope']
# JC Gaming
# ['panel-match-detail', 'ng-scope']
# Reason
#    MatchID Date TeamID                 Team Moneyline HDP Map1 Map2 Map3
# 0        0    0      0            GrayHound      1.98   0    0    0    0
# 1        0    0      0                TyLoo      1.76   0    0    0    0
# 0        1    0      0               Gambit      1.24   0    0    0    0
# 1        1    0      0        Vega Squadron      3.81   0    0    0    0
# 0        2    0      0             Infamous      4.42   0    0    0    0
# 1        2    0      0                  LGD      1.20   0    0    0    0
# 0        3    0      0                   OG      1.64   0    0    0    0
# 1        3    0      0           TnC Gaming      2.22   0    0    0    0
# 0        4    0      0                Na`Vi      2.10   0    0    0    0
# 1        4    0      0           Virtus.pro      1.71   0    0    0    0
# 0        5    0      0                  LGD      1.40   0    0    0    0
# 1        5    0      0            VGJ.Storm      2.90   0    0    0    0
# 0        6    0      0               LGD.FY      1.58   0    0    0    0
# 1        6    0      0           TnC Gaming      2.34   0    0    0    0
# 0        7    0      0             Infamous      4.72   0    0    0    0
# 1        7    0      0                   OG      1.18   0    0    0    0
# 0        8    0      0                EHOME      2.47   0    0    0    0
# 1        8    0      0           Virtus.pro      1.52   0    0    0    0
# 0        9    0      0                Na`Vi      1.85   0    0    0    0
# 1        9    0      0           TnC Gaming      1.93   0    0    0    0
# 0       10    0      0             Infamous      4.46   0    0    0    0
# 1       10    0      0               LGD.FY      1.20   0    0    0    0
# 0       11    0      0                   OG      1.30   0    0    0    0
# 1       11    0      0            VGJ.Storm      3.46   0    0    0    0
# 0       12    0      0      Korea All-Stars      1.11   0    0    0    0
# 1       12    0      0     Turkey All-Stars      5.73   0    0    0    0
# 0       13    0      0      China All-Stars      1.19   0    0    0    0
# 1       13    0      0     Brazil All-Stars      4.25   0    0    0    0
# 0       14    0      0                 Pray      1.38   0    0    0    0
# 1       14    0      0             SwordArT      2.84   0    0    0    0
# ..     ...  ...    ...                  ...       ...  ..  ...  ...  ...
# 0        6    0      0          Team Empire      1.26   0    0    0    0
# 1        6    0      0             WG.Unity      3.57   0    0    0    0
# 0        7    0      0                EHOME         0   0    0    0    0
# 1        7    0      0                  LGD         0   0    0    0    0
# 0        8    0      0           TnC Gaming      2.10   0    0    0    0
# 1        8    0      0           Virtus.pro      1.72   0    0    0    0
# 0        9    0      0             Infamous      4.22   0    0    0    0
# 1        9    0      0                Na`Vi      1.22   0    0    0    0
# 0       10    0      0               LGD.FY      1.40   0    0    0    0
# 1       10    0      0            VGJ.Storm      2.91   0    0    0    0
# 0       11    0      0                  LGD      2.29   0    0    0    0
# 1       11    0      0                   OG      1.61   0    0    0    0
# 0       12    0      0                EHOME      2.13   0    0    0    0
# 1       12    0      0           TnC Gaming      1.70   0    0    0    0
# 0       13    0      0             Infamous      4.74   0    0    0    0
# 1       13    0      0           Virtus.pro      1.18   0    0    0    0
# 0       14    0      0                Na`Vi      1.50   0    0    0    0
# 1       14    0      0            VGJ.Storm      2.55   0    0    0    0
# 0       15    0      0                 INTZ      1.73   0    0    0    0
# 1       15    0      0             Team One      1.99   0    0    0    0
# 0       16    0      0       Operation Kino      1.60   0    0    0    0
# 1       16    0      0               T Show      2.20   0    0    0    0
# 0       17    0      0  Royal Never Give Up      1.77   0    0    0    0
# 1       17    0      0       Team Celestial      1.96   0    0    0    0
# 0       18    0      0            KSV Black      1.29   0    0    0    0
# 1       18    0      0       Team Ballistix      3.25   0    0    0    0
# 0       19    0      0            JC Gaming      1.66   0    0    0    0
# 1       19    0      0         eStar Gaming      2.11   0    0    0    0
# 0       20    0      0               Reason      1.37   0    0    0    0
# 1       20    0      0             Endpoint      2.90   0    0    0    0
#
# [246 rows x 9 columns]
